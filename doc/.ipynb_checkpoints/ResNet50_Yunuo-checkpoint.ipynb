# %% [markdown]
# # ResNet50 Implementation

# %% [markdown]
# 1. Skip steps from "Crop Images to 256x256x3" to "Save the preproccessed as data.h5 file" if you only want to reproduce the model based on data we have; Start from beginning if you have new data.
# 2. The feature process for the model is quite long. You can directly download the model from [ResNet50](https://drive.google.com/file/d/17gfalgEEV5UQ9XLYt95Ehcha7JHY0qhG/view) and then load the model by running model = load_model('your path with model').

# %% [markdown]
# ## Load Required packages

# %%
from numpy.random import seed
seed(5243)
import tensorflow
tensorflow.random.set_seed(5243)
from keras import layers
from keras.layers import Input, Add, Dense, Dropout, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
import h5py
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import roc_curve, auc
import glob
import os
import pydot
import numpy as np
import cv2
import csv
import time
import skimage.io
from PIL import Image
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# WARNING:tensorflow:From <ipython-input-1-15776b5019f6>:37: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Crop Images to 256x256x3

# %%
your_path = "/Users/Stephanie/Documents/GitHub/Fall2020-Project3-group_3"
os.chdir(your_path)
path = os.getcwd()

class FaceCropper(object):
    CASCADE_PATH = path + "/lib/haarcascade_frontalface_default.xml"

    def __init__(self):
        print(self.CASCADE_PATH)
        self.face_cascade = cv2.CascadeClassifier(path + "/lib/haarcascade_frontalface_default.xml")
        

    def generate(self, image_path, show_result=False, d = 0):
        img = cv2.imread(image_path)
        if (img is None):
            print("Can't open image file")
            return 0

        #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = self.face_cascade.detectMultiScale(img, 1.1, 5, minSize=(100, 100))
        facecnt = len(faces)
        print("Detected faces: %d" % facecnt)

        if (faces is None):
            return faces
        elif len(faces) > 1:
            eval = []

            # solve the issue when there are multiple detection
            for face in faces:
                x,y,w,h = face
                r = max(w, h) / 2
                size = r*2
                eval.append(size)
            ind = eval.index(max(eval))
            faces = faces.tolist()
            faces = [faces[ind]]

        # zoom a bit more than usual
        for (x, y, w, h) in faces:
            newx, newy,neww,newh = x+d,y+d,w-d,h-d
            r = max(neww, newh) / 2
            centerx = newx + neww / 2
            centery = newy + newh / 2
            nx = int(centerx - r)
            ny = int(centery - r)
            nr = int(r * 2)
            faceimg = img[ny:ny+nr, nx:nx+nr]
            lastimg = cv2.resize(faceimg, (256, 256))

            return lastimg

        if (show_result):
            for (x, y, w, h) in faces:
                newx, newy, neww, newh = x, y, w - d, h - d
                cv2.rectangle(img, (newx, newy), (newx+neww, newy+newh), (255,0,0), 2)
            cv2.imshow('img', img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

if __name__ == '__main__':
   
    image_path = path + "/data/train_set/images"
    if not os.path.exists(path + '/data/data_1'):
        os.makedirs(path + '/data/data_1')
    destination = path + "/data/data_1"
    if not os.path.isdir(destination):
        os.makedirs(destination)
    if os.path.isdir(image_path):
        file_names = glob.glob(image_path+"/*.jpg")
        faceDetector = FaceCropper()
        for i in range(len(file_names)):
            name = file_names[i]
            print(name)
            result = faceDetector.generate(name)
            if result is None:
                result = faceDetector.generate(file_names[i + 1])
                resname = destination + "/" + os.path.basename(name)
                cv2.imwrite(resname, result)

            else:
                resname = destination + "/" + os.path.basename(name)
                cv2.imwrite(resname, result)

        print("The Face Chopping is done!")
# Out:
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/lib/haarcascade_frontalface_default.xml
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0071.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2666.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2100.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0717.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1409.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0703.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2114.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2672.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0065.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2882.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1353.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1435.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2128.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1421.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1347.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0059.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2896.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0918.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2869.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1390.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2699.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2841.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0930.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0924.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2855.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1384.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0515.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2302.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2464.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0273.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0267.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1179.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2470.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2316.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0501.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1637.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0529.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1151.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2458.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1145.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1623.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1810.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1804.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1192.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1186.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0298.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1838.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0461.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2276.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2510.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1019.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0307.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0313.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2504.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2262.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0475.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1743.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1025.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2538.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1031.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0449.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1757.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1964.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1970.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1780.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1958.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2289.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1794.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0105.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2712.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2074.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0663.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1569.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0677.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2060.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2706.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0111.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0139.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1227.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0887.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1541.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2048.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0893.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1555.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1233.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2909.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0878.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2935.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0844.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1582.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0688.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0850.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1596.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2921.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1597.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0851.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0689.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2920.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2934.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1583.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0845.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2908.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0879.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1554.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0892.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1232.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1226.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0138.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2049.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1540.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0886.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2061.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0676.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1568.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0110.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2707.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2713.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0104.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0662.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2075.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1795.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2288.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1959.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1781.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1971.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1965.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1030.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2539.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1756.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0448.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1742.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1024.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2505.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0312.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0474.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2263.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2277.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0460.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0306.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1018.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2511.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0299.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1187.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1839.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1193.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1805.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1811.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1144.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1622.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0528.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1636.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2459.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1150.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2471.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1178.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0266.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0500.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2317.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2303.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0514.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0272.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2465.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0925.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1385.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2854.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2840.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2698.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1391.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0931.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0919.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2868.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1420.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2129.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2897.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0058.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1346.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1352.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2883.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1434.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2115.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0702.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0064.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2673.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2667.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0070.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1408.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0716.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2101.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2671.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1378.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0066.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0700.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2117.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2103.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0714.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0072.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2665.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1344.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2895.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1422.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0728.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1436.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2881.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2659.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1350.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2856.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0099.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1387.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0927.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0933.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1393.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2842.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2315.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0502.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0264.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2473.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2467.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0270.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1608.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0516.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2301.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1620.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2329.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0258.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1146.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1152.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1634.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1807.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1813.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1185.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2498.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1191.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2261.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0476.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1768.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0310.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2507.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2513.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0304.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0462.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2275.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1754.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1032.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1026.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0338.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2249.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1998.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1740.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1973.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1967.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1797.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0489.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1783.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2705.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0112.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0674.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2063.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2077.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0660.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0106.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1218.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2711.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1230.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2739.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0890.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1556.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0648.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0884.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1542.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1224.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2922.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0853.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1595.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2088.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0847.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1581.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2936.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1580.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0846.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2089.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2937.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2923.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1594.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0852.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1543.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0885.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1225.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2738.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1231.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0649.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1557.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0891.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0661.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2076.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2710.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1219.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0107.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0113.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2704.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2062.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0675.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1782.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0488.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1796.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1966.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1972.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0339.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1027.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1741.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1999.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2248.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1755.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1033.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0305.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2512.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2274.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0463.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1769.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0477.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2260.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2506.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0311.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1190.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2499.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1184.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1812.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1806.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1153.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1635.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2328.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1621.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1147.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0259.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0271.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2466.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2300.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0517.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1609.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0503.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2314.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2472.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0265.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0932.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2843.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1392.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1386.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0098.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2857.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0926.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1437.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0729.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1351.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2658.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2880.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2894.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1345.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1423.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0715.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2102.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2664.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0073.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0067.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1379.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2670.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2116.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0701.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0739.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1427.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1341.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2890.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2648.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2884.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1355.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1433.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0705.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2112.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2674.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0063.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1369.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0077.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2660.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2106.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0711.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0922.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2853.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1382.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0088.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1396.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2847.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0936.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1143.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1625.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2338.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1631.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0249.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1157.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0261.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2476.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2310.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1619.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0507.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0513.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2304.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2462.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0275.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1180.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2489.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1194.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1802.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1816.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1037.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0329.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1989.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1751.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2258.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1745.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1023.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0315.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2502.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2264.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0473.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0467.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1779.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2270.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2516.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0301.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1792.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1786.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0498.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1976.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1962.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1553.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0895.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1235.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2728.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1221.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1547.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0881.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0659.jpg
# Detected faces: 1
# ...
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0479.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1767.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1773.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1015.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0323.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2534.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2252.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0445.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1983.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0451.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1997.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2246.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2520.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1029.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0337.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1968.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1798.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0486.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1940.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2291.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2285.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0492.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1954.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1565.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1203.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0109.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1217.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1571.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2078.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1559.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0647.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2050.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2736.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0121.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0135.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2722.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2044.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0653.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0860.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2911.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2905.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0874.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2093.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0684.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2939.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0690.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0848.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2087.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2938.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2086.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0849.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0691.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0685.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2092.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2904.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0875.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0861.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2910.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2723.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0134.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0652.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2045.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2051.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0646.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1558.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0120.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2737.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1216.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0108.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2079.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1570.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1564.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1202.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1955.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0493.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2284.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2290.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1941.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0487.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1799.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1969.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2247.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1996.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0450.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0336.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1028.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2521.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2535.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0322.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1982.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0444.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2253.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1772.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1014.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1000.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2509.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1766.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0478.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1821.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2496.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0281.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0295.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2482.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1835.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1809.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2333.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0524.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0242.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2455.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2441.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1148.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0256.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0530.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2327.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0518.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1606.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2469.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1160.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1174.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1612.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0083.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2694.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0929.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2858.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2680.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1389.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0097.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2870.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0901.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0915.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2864.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2657.jpg
# Detected faces: 2
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0040.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1438.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0726.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2131.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2125.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0732.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0054.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2643.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1362.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1404.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1410.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/2119.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/0068.jpg
# Detected faces: 1
# /Users/stephanie/Documents/GitHub/Fall2020-Project3-group_3/data/train_set/images/1376.jpg
# Detected faces: 1
# The Face Chopping is done!

# %% [markdown]
# ## Classify images

# %%
path = os.getcwd()
read_path = path + "/data/data_1"


save_path = path + '/data/data_2'
if not os.path.exists(save_path):
    os.makedirs(save_path)
import pandas as pd 
data = pd.read_csv(path + "/data/train_set/label.csv") 
file_list = sorted(os.listdir(read_path))
lab = data['label']

for i in range(len(file_list)):
    label = str(lab[i])
    subfolder = os.path.join(save_path, label)
    image = file_list[i]
    if not os.path.exists(subfolder):
        os.makedirs(subfolder)
    img = cv2.imread(os.path.join(read_path, image))
    img = cv2.resize(img, (64, 64))
    cv2.imwrite(os.path.join(subfolder, image), img)

print("Image classification is done!")
# Out:
# Image classification is done!

# %% [markdown]
# ## Save the preproccessed as data.h5 file

# %%
path = os.getcwd()
data_path = path + '/data/data_2'

c0_path = os.path.join(data_path, '0')
c1_path = os.path.join(data_path, '1')


# # Creat the list to store the data and label information
data_x = []
data_y = []


datapath = os.path.join(path + '/data/h5','data.h5')
if not os.path.exists(os.path.dirname(datapath)):
    os.makedirs(os.path.dirname(datapath))

# order the file, so the training set will not contain the test set (don't random)
files = os.listdir(c0_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(c0_path,filename))
    data_x.append(I.tolist())
    data_y.append(0)

files = os.listdir(c1_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(c1_path,filename))
    data_x.append(I.tolist())
    data_y.append(1)

print(np.shape(data_x))
print(np.shape(data_y))

datafile = h5py.File(datapath, 'w')
datafile.create_dataset("data_pixel", dtype = 'uint8', data=data_x)
datafile.create_dataset("data_label", dtype = 'int64', data=data_y)
datafile.close()

print("Save data finish!")
# Out:
# (3000, 64, 64, 3)
# (3000,)
# Save data finish!

# %% [markdown]
# ## Deal with imbalanced data for all

# %%
X_orig = np.array(h5py.File(os.getcwd()+ '/data/h5/data.h5', "r")["data_pixel"][:]) 
Y_orig = np.array(h5py.File(os.getcwd()+ '/data/h5/data.h5', "r")["data_label"][:])

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(Y_orig[Y_orig==1])))
print("Before OverSampling, counts of label '0': {} \n".format(len(Y_orig[Y_orig==0])))

from imblearn.over_sampling import SMOTE 
from imblearn.over_sampling import SVMSMOTE 
smote = SMOTE()
X_orig_smote, Y_orig_smote = smote.fit_sample(X_orig.reshape(X_orig.shape[0], -1), Y_orig.ravel()) #1914 0, 1914 1
X_orig_smote = X_orig_smote.reshape(X_orig_smote.shape[0], 64, 64, 3)

print("After OverSampling, counts of label '1': {}".format(sum(Y_orig_smote[Y_orig_smote==1]))) 
print("After OverSampling, counts of label '0': {}".format(len(Y_orig_smote[Y_orig_smote==0])))
# Out:
# Before OverSampling, counts of label '1': 598
# Before OverSampling, counts of label '0': 2402
#
# After OverSampling, counts of label '1': 2402
# After OverSampling, counts of label '0': 2402

# %% [markdown]
# ## Train test data split

# %%
def load_dataset():
#     path1 = os.getcwd()
#     data_path1 = path1 + '/data/h5/data.h5'
#     train_dataset = h5py.File(data_path1, "r")
#     X_orig = np.array(train_dataset["data_pixel"][:]) # your train set features
#     Y_orig = np.array(train_dataset["data_label"][:]) # your train set labels
    X_train, X_test, y_train, y_test = train_test_split(X_orig_smote, Y_orig_smote, test_size=0.2, random_state=5243)
    y_train = y_train.reshape((1, y_train.shape[0]))
    y_test = y_test.reshape((1, y_test.shape[0]))
    
    return X_train, y_train, X_test, y_test

# %%
def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset() #2400 train data, 600 test data

# %% [markdown]
# ## Normalize image vectors and convert training and test labels to one hot matrices

# %%
# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 2).T
Y_test = convert_to_one_hot(Y_test_orig, 2).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 3843
# number of test examples = 961
# X_train shape: (3843, 64, 64, 3)
# Y_train shape: (3843, 2)
# X_test shape: (961, 64, 64, 3)
# Y_test shape: (961, 2)

# %% [markdown]
# ## Build Resnet Model

# %%
def identity_block(X, f, filters, stage, block):
    """
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value.
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
      
    # Second component of main path 
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
       
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X

    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path 
    X = Conv2D(F2, (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(F3, (1, 1), strides = (1,1), name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 2):
    """
    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)
    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3 
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4 
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5 
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL
    X = AveragePooling2D(pool_size=(2, 2), name = 'avg_pool')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
   
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

# %% [markdown]
# ## Configure the Learning Process by Compiling the Model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 2)
start_time = time.time()
model.compile(optimizer='adam',loss="binary_crossentropy", metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 20, batch_size = 64)
print("training  model takes %s seconds" % round((time.time() - start_time),3))
# Out:
# Epoch 1/20
# 61/61 [==============================] - 93s 2s/step - loss: 0.6209 - accuracy: 0.7689
# Epoch 2/20
# 61/61 [==============================] - 91s 1s/step - loss: 0.4737 - accuracy: 0.8004
# Epoch 3/20
# 61/61 [==============================] - 91s 1s/step - loss: 0.4975 - accuracy: 0.7531
# Epoch 4/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3785 - accuracy: 0.8246
# Epoch 5/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4798 - accuracy: 0.7505
# Epoch 6/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4147 - accuracy: 0.8124
# Epoch 7/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4763 - accuracy: 0.7817
# Epoch 8/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4892 - accuracy: 0.7778
# Epoch 9/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.5249 - accuracy: 0.7455
# Epoch 10/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4646 - accuracy: 0.7681
# Epoch 11/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.4440 - accuracy: 0.7700
# Epoch 12/20
# 61/61 [==============================] - 94s 2s/step - loss: 0.4290 - accuracy: 0.8033
# Epoch 13/20
# 61/61 [==============================] - 94s 2s/step - loss: 0.3611 - accuracy: 0.8384
# Epoch 14/20
# 61/61 [==============================] - 93s 2s/step - loss: 0.3961 - accuracy: 0.8189
# Epoch 15/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3318 - accuracy: 0.8483
# Epoch 16/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.2993 - accuracy: 0.8689
# Epoch 17/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3096 - accuracy: 0.8639
# Epoch 18/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3811 - accuracy: 0.8272
# Epoch 19/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3671 - accuracy: 0.8342
# Epoch 20/20
# 61/61 [==============================] - 92s 2s/step - loss: 0.3374 - accuracy: 0.8587
# training  model takes 1877.718 seconds

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 31/31 [==============================] - 3s 112ms/step - loss: 0.4046 - accuracy: 0.8231
# Loss = 0.404598593711853
# Test Accuracy = 0.8231009244918823

# %% [markdown]
# ## ROC curve with AUC

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
y_score = model.predict(X_test)
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(Y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = itertools.cycle(['blue', 'red'])

for i, color in zip(range(2), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=1,
             label='ROC curve of class {0} (area = {1:0.3f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=1)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for binary data')
plt.legend(loc="lower right")
plt.show()

# %%
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 32, 32, 64)   9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 32, 32, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 15, 15, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 15, 15, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 15, 15, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 15, 15, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 15, 15, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 15, 15, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 15, 15, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 15, 15, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 15, 15, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 15, 15, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 15, 15, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 15, 15, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 15, 15, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 15, 15, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 15, 15, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 15, 15, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15, 15, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 15, 15, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 15, 15, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 15, 15, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 15, 15, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 15, 15, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 15, 15, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 15, 15, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 15, 15, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15, 15, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 15, 15, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 15, 15, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 15, 15, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15, 15, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 8, 8, 128)    32896       activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 8, 8, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 8, 8, 128)    147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 8, 8, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 8, 8, 512)    66048       activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 8, 8, 512)    131584      activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 8, 8, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 8, 8, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 512)    0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 8, 8, 128)    65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 8, 8, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 8, 8, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 8, 8, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 8, 8, 512)    66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 8, 8, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 8, 8, 128)    65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 8, 8, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 8, 8, 128)    147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 8, 8, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 8, 8, 512)    66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 8, 8, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 8, 8, 128)    65664       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 8, 8, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 8, 8, 128)    147584      activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 8, 8, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 8, 8, 512)    66048       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 8, 8, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 4, 4, 256)    131328      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 4, 4, 1024)   525312      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 4, 4, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 1024)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 4, 4, 256)    262400      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 4, 4, 256)    262400      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 4, 4, 256)    262400      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 4, 4, 256)    262400      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 4, 4, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4, 4, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 4, 4, 256)    262400      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 4, 4, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 4, 4, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 4, 4, 256)    590080      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 4, 4, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 4, 4, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 4, 4, 1024)   263168      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 4, 4, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 4, 4, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 2, 2, 512)    524800      activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 2, 2, 2048)   2099200     activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 2, 2, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 2, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 2, 2, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 2, 2, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 2)            4098        flatten[0][0]
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## Plot our ResNet50 model

# %%
plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %% [markdown]
# ## Save Model

# %%
model.save('/Users/Stephanie/Documents/GitHub/Fall2020-Project3-group_3/output/ResNet50.h5')

# %%
del model
model =load_model('/Users/Stephanie/Documents/GitHub/Fall2020-Project3-group_3/output/ResNet50.h5')
